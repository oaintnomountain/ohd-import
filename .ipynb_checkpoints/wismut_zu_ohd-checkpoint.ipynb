# %% [markdown]
# Setup

# %%
import sys, os

# %% [markdown]
# Read the Wismut API

# %%
def read_api(urlpath):
    import requests
    if not urlpath:
        print('es muss eine gültige URL an die Funktion read_api übergeben werden!')
        return
    headers={'Accept' : 'application/json'}
    r=requests.get(url=urlpath, headers=headers)
    if r:
        try:
            data=r.json()
            return data
        except requests.exceptions.JSONDecodeError as e:
            print('JSON Daten konnten nicht verarbeitet werden:',e)
    else:
        print('Fehler bei Abfrage der URL:',urlpath,'mit Fehlercode:',r.status_code)
        return

def pars_data(data,searchlist):
    import json
    if not data:
        print('Keine Daten zum Durchsuchen an die Funktion pars_data übergeben.')
        return
    if not searchlist:
        print('Keine Liste mit zu suchenden Begriffen angegeben')
        return
    for searchterm in searchlist:
        print(searchterm)
    print(type(data))
    print(data)

def find_interviews(data):
    interviews = []
    if not data:
        print('Keine Daten zum Durchsuchen an die Funktion find_interviews übergeben.')
        return
    for item in data['items']:
        interviews.append(item['@id'])
    print(interviews)
    return interviews

def parse_interviews (urls):
    interviews_metadaten = []
    if not type(urls) == list:
        print('Es wurde keine passende Liste mit URLs an die Funktion parse_interviews übergeben')
        return
    for url in urls:
        data = read_api(url)
        metadaten = find_metadata_in_interview(data)
        interviews_metadaten.append(metadaten)
    return interviews_metadaten

def find_metadata_in_interview(data):
    import datetime
    metadaten = {}
    if not type(data) == dict:
        print('Keine Daten im passenden Format an die Funktion find_metadata_in_interview gefunden')
        return
    metadaten = {
        'Orig_ID' : data['UID'],
        'Medium' : 'Video',
        'Language' : data['language']['token'],
        'Date_of_Interview' : data['edtf_date'],
        'Length' : str(datetime.timedelta(seconds=data['duration'])),
        'Accessibility' : 'Online Open Access',
        'Interviewer' : data['interviewer'][0]['title'],
        'Indexing' : data['subjects'],
        'link' : data['@id'],
        'Interviewtyp' : data['taxonomy_interview_types']['title']
    }
    for person in data['persons_interviewed']:
        print('person URL:', person['@id'])
    print(metadaten)
    return metadaten



def main(*starturl):
    if not starturl:
        starturl = "https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews"
    rdata = read_api(starturl)
    print(type(rdata))
    searchfor = ('items','@id')
    print(type(searchfor))
    #pars_data(rdata,searchfor)
    interviewliste = find_interviews(rdata)
    print(type(interviewliste))
    metadaten = parse_interviews(interviewliste)

    #print(rdata)


if __name__ == '__main__':
    main()
# Out:
# <class 'dict'>
# <class 'tuple'>
# ['https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-andrejew-georgij-georgiewitsch', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-baumann-regina-und-baumann-rommy', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-jutta-bergholz', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-bohnwagner-elfriede', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-brumme-reiner', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-daenecke-rudolf', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-nindel-kerstin', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-ducke-dr-guenter', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-fischer-hans-georg', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-freyer-bernd-prof-dr', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-friedrich-klaus-dr', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-geyer-siegfried', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-gorbatschjow-jurij-michajlowitsch', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-gorbatschjow-jurij-michajlowitsch-2020', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-gruendel-gisela', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-karl-heinz-gruendel', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-haertel-christa', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-hauschild-lothar-und-hannelore', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-heuser-michael', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/2021-02-19-gertraude-johanna-hummel-480p.mp4', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-jokisch-eva-maria', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-kiepsch-karsten', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-kiepsch-ramona', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-kircheis-lothar', 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-kreisel-wirth-petra-1']
# <class 'list'>
# person URL: https://wismut.saw-leipzig.de/api/de/personen/georgi-georgiewitsch-andrejew
# {'Orig_ID': '735c5cf99ee848f4866a37ac743b5881', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-03-19', 'Length': '3:00:00', 'Accessibility': 'Online Open Access', 'Interviewer': 'Yaroslav Koshelev', 'Indexing': ['Lokomotivfabrik Luhansk', 'Zweiter Weltkrieg', 'Sibirien', 'Evakuation', 'Fliegerangriff', 'Omsk', 'Kindheitserinnerungen', 'Krieg', 'Überleben', 'Vater', 'Hauptingenieur', 'Schule', 'Charkiw', 'Hochschule für Bergbau der UdSSR Charkiw', 'WNIIOMSchS', 'Abteilung für Mechanisierung', 'wissenschaftliche Tätigkeit', 'Patente', 'Aspirantur', 'Doktor', 'Dissertation', 'Kandidat der Wissenschaften', 'SDAG Wismut', 'Kadermangel', 'Spezialisten', 'Leitender Ingenieur', 'Abteilungsleiter', 'Leiter der Abteilung für Mechanisierung', 'Ventilation', 'Belüftung', 'Errichtung von Fördertürmen', 'Förderturm', 'Planvorgaben', 'Drosen', 'Arbeitsaufgabe', 'Geschichte der Wismut', 'Kriegshandlungen', 'Uranerzvorkommen', 'Geschichte des Bergbaus', 'Uranfarben', 'Pechblende', 'Lungenkrebs', 'Schneeberger Krankheit', 'Uransuche', 'SBZ', 'Erkundungsarbeiten', 'alte Bergwerke', 'Zusammenarbeit mit Obersteigern', 'Halden', 'Geologische Berichte', 'Feldpost 27304', 'SMERSch', 'Anwerbung', 'ungeeignete Arbeiter', 'Geflüchtete', 'Vertriebene', 'Schlesien', 'Schlesier', 'Städtebau', 'Komfort', 'Reparationen', 'Bergbaureviere', 'Gewerkschaft', 'vereintes Deutschland', 'DDR', 'Kalter Krieg', 'Uranmangel', 'Uranlücke', 'Vorkommen in der UdSSR', 'Forcierung der Uranförderung', 'Gegnerschaft mit der BRD', 'Informationskrieg', 'Gerüchte', 'falsche Gerüchte', 'Meldungen', 'Nachrichten', 'Unfälle', 'Havarien', 'Brand', 'Johanngeorgenstadt', 'Soldaten als Bergmänner', 'Radiometristen', 'Antisowjetische Propaganda', 'RIAS', 'Falschmeldungen', 'Bergmannskodex', 'Bergmannstradition', 'Malzew', 'GULAG', 'Generaldirektor', 'SAG Wismut', 'Reformen um 1954', 'Ausbildungszentren', 'Bergmannsschulen', 'Bergmannshochschulen', 'Klaustrophobie', 'Frauen unter Tage', 'Gehalt unter Tage', 'Versorgung', 'Prämien', 'Zuschläge', 'Berufe der Frauen', 'Proteste der Frauen', 'Deutsche Sprache', 'Sprachkurse', 'Wismut-Sprache', 'Vertreter der Hauptingenieurs', 'Technischer Direktor', 'Technologietransfer', 'Kopien', 'Technologie der Wismut', 'Geräte der Wismut', 'Laugung', 'Auswahlverfahren der sowjetischen Spezialisten', 'Dissertationsthema', 'Anreise in die DDR', 'Brände', 'Verfüllung', 'Freizeit', 'Aufgaben', 'Arbeitsablauf', 'Beziehungen zwischen sowjetischen und deutschen Kollegen', 'Staat im Staat', 'Geheimhaltung', 'Unzulänglichkeiten der Geheimhaltung', 'Autarkie', 'Selbstversorgung', 'Privilegien', 'Nahrung', 'Stalinpaket', 'Gehalt', 'Gefahren', 'Krankheiten', 'Sicherheitsvorkehrungen', 'Trockenbohren', 'Staub', 'Bohren', 'Nassbohren', 'Widrigkeiten', 'deutsch-sowjetische Freundschaft', 'Randale', 'Aufstand', '1953', '17. Juni 1953', 'Saalfeld', 'Revolte in Saalfeld', '16. August 1951', 'CIA', 'Stalinallee', 'Geheimdienst', 'Provokateure', 'BRD', 'Berliner Mauer', 'Sanierung', 'Rekultivierung', 'Umwelt', 'Umweltproteste', 'Traditionsverein', 'Geschichtsbuch', 'Buch'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-andrejew-georgij-georgiewitsch', 'Interviewtyp': 'Zeitzeugeninterview'}
# {'Orig_ID': '6d2bdeb1f2f44c2494c340d7c60745e7', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2020-12-16', 'Length': '2:14:58', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Maxim Gorki Theater', 'Mauerbau', 'Mauerfall', 'Staatsoper', 'Neustadt', 'Mittelstadt', 'Altstadt', 'Entwicklung Johanngeorgendorf', 'Sockendorf', 'Anfänge Wismut', 'Geteiltes Berlin', 'Handschumacherstadt', 'Politisches Engagement', 'Einquartierung von Bergarbeitern', 'Schwibbogen', 'Silikose', 'Krebs', 'Westfernsehen', 'Bergmannskrankheit', 'Sonderrechte', 'Privilegien', 'Denkmalschutz', 'Haldensanierung', 'Haldenlandschaft', 'Sperrgebiet Erzgebirge', 'Rannle', 'Arbeitslosigkeit in der DDR', 'Hausfrauen in der DDR', 'Handschuhindustrie', 'Textilindustrie', 'Umweltschutz', 'Biermann-Ausbürgerung', 'Radon', 'Korbmacherei', 'DDR-Flucht', 'Stasi-Verfolgung', 'SED', 'KPD', 'Frauen für den Frieden', 'Stadtbild Johanngeorgenstadt', 'Lungenkrebs', 'Bronchialkarzinom', 'Leukämie', 'Niedrigstrahlung', 'Strahlung', 'Atomenergie', 'Opposition', 'Ausreisesperre', 'Ausreise', 'Festnahme', 'Lindencorso', 'Prenzlauer Berg', 'Johannsibirsk', 'Rumänien', 'Bulgarien', 'Ungarn', 'Erzgebirge', 'West-Erzgebirge', 'Ost-Erzgebirge'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-baumann-regina-und-baumann-rommy', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/jutta-bergholz
# {'Orig_ID': 'ff36b31851fe4d75abac99408de222b2', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2020-09-24', 'Length': '2:17:20', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Arbeit', 'Arbeitsbedingungen', 'Erinnerungen', 'Frühzeit der Wismut', 'Kultur', 'Kulturarbeit', 'Soziale Situation', 'sowjetische Bergleute', 'Landschaftswandel', 'persönliche Erlebnisse', 'Leben in Bezug auf die Wismut', 'faschistischen Zeit', 'Reichstagsabgeordneter der SPD', 'Mädchenklasse', 'Breitungen an der Werra', '1954', 'Gera', 'Konsum', '46 [1946]', 'Landeskreditbank', 'Coupons', 'Kindergartenplatz', 'Wismut', 'Jugendbergbaubetrieb', 'Verwaltung', 'Objekt 90', 'Verwaltung des Objektes 90', 'Bergbaubetriebe', 'Hilfsbetriebe', 'Transportbetriebe', 'mechanische Werkstatt', 'Planabteilung', 'SDAG', 'Russisch', 'Volkshochschule', 'kyrillischen Buchstaben', 'Formulare', 'Journale', 'Abteilungsleiter', 'sowjetischen Kollegen', 'Arbeiten', 'Spaß', '40. Jahrestag der Oktoberrevolution', 'gefeiert 14 Tage lang', 'Geologe', 'Erzqualitäten', 'Silikat- und Carbonatprozess', 'Gewichtung', 'Aufbereitungsbetriebe', 'Erze', 'einen roten Strich', 'Formular', 'geheim', 'Aktentasche', 'Verschlussabteilung', 'kontrolliert', 'Ordnung', 'Stempel', 'Unordnung', '1971', 'Objekt 9', 'aufgelöst', 'Aue-Betriebe', 'Schlema', 'Aue', 'Privilegien', 'BS', 'Betriebsschule', 'BBS', 'Betriebsberufsschule', 'polytechnische Ausbildung', 'Erwachsenenqualifizierung', 'Weiterbildung', 'Ingenieurausbildung', 'Schulgebäude', 'Lehrlinge', 'theoretischen', 'Internat', 'Schwimmhalle', 'Sporthalle', 'Baracke', 'Versorgung', 'Wismut-Handel', 'Vollverpflegung', 'Seilfahrt', 'Frühschicht', 'Jugendlichen', 'Herausforderung', 'Disko', 'Beschäftigte', 'Großbetrieb', 'Lehrer', 'Erzieher', 'Zwischentrakte', 'kulturelle', 'Frauen', 'Zimmer', 'sauber', 'Friedensfahrt', 'Zeulenroda', 'Sepp Wenig', 'Kulturgruppen', 'Singeklub', 'Tanzgruppe', 'Orchersterleiter', 'Theater', 'Bläsergruppe', 'Instrumente', 'Staatshaushalt', 'finanziert', 'Theorie', 'Wohnheim', 'Bergleute', 'Reust', 'Bauausbildung', 'BMB 17', 'Baubetrieb', 'Praxis', 'Seelingstädter', 'Aufbereitung', 'Chemieausbildung', 'Lehrmeister', 'Planung', 'Abendstudium', 'Fachschule', 'Oberschule', 'Objekt', 'Betriebe', 'Chaos', 'Atmosphäre', 'freundschaftliche', 'Abteilung', 'Sachbearbeiterin', 'Arbeitsverhältnis', 'Frauenausschusses', 'Mitglied', 'Frauenkommission', 'Mitgliedschaften', 'Betrieb', 'Chemnitz', 'Leitung der Gewerkschaft', 'Zentralvorstandes', 'Abgesandte', 'Frauenförderungsplan', '8. März-Veranstaltung', 'Festveranstaltung', 'Bilder', 'Arbeitskräfte', 'Löhne', 'Lebenshaltung', 'Kollegen', 'Frauen in leitende Funktionen', 'Ende', 'Funktion', 'Stellvertreter des Direktors', 'Ökonomie', 'Wirtschaftsabteilung', 'Heime', 'Acht-Stunden-Tag', 'Stellvertreterin', 'Generaldirektors für Ökonomie', 'Buchhaltung', 'Hauptbuchhalter', 'Drosen', 'leitende', 'Frauenklasse', 'Ökonomie-Ingenieursstudium', 'Haushalt', 'Kinder', 'nicht so zugetraut', 'Arbeitsalltag', 'Leitungsfunktion', 'Tag', 'Arbeitsberatung', 'Mitarbeitern', 'Handwerker', 'Bergarbeiter', 'rehabilitiert', 'Einsatz', 'Persönlichkeiten', 'Freiheit', 'diszipliniert', 'Umformer', 'Schwimmmeister', 'Arbeitszeit', 'Schwimmkurs', 'Wochenenden', 'Feierlichkeiten', 'Auftritte', 'Jugendlager', 'Ostsee', 'Zinnowitz', 'Erzgebirge', 'Mark', 'Aufenthalt', 'Männer', 'fehlten uns die Mädchen', 'Lager', 'Einheimischen', 'Mädchen', 'Krankehaus', 'Zelte', 'Küchenpersonal', 'Berichten', 'Konferenzen', 'Pläne', 'Gelände', 'Kleinarbeit', 'Pädagogen', 'Lehrerleistung', 'Schülerleistung', 'Abschluss', 'Praxis und Theorie', 'Berufsausbildung', 'Lehrrevier', 'Bohrmaschinen', 'Gehörschutz', 'aufpassen', 'Gruppe', 'GAS', 'Gesundheits-Arbeitsschutz', 'trockenbohrten', 'Silikose', 'Schutz', 'Wasser', 'Lehrberufe', 'Werbung', 'Facharbeiter Bergbau', 'Bau', 'Abiturklasse', 'Chemie', 'Nachwuchs', 'Hauer', 'Steiger', 'Ausbildung Facharbeiter Bergbautechnologie' ...
# person URL: https://wismut.saw-leipzig.de/api/de/personen/elfriede-bohnwagner
# {'Orig_ID': '8cad35f12698446ca10c3020cd112384', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-06-10', 'Length': '2:08:49', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Kindheit', 'Tod der Mutter', 'Familiengeschichte', 'Anwerbung bei der Wismut', 'Objekt 11', 'drei Schichten', 'Arbeit', 'Bau', 'Frauenarbeit', 'Bauabschnitt', 'Zimmererbrigade', 'Henneckesiedlung', 'Tanz', 'Kulturhaus', 'Schlägerei', 'Mann', 'Ehemann', 'Kind', 'Straßenbau', 'Schwangerschaft', 'Erkrankung des Kindes', 'Tochter', 'Kindergarten', 'Kinderheim', 'ungelernte Kraft', 'Kindergesundheit', 'Krippenhelferin', 'Ausbildung', 'Krippenerzieher', 'vier Kinder', 'Teilzeitarbeit', 'Konflikt mit Chefin', 'Wohnung', 'Sohn', 'Geophysiker', 'Röntgenzug', 'Krankheit', 'Lungenkrankheit', 'Umschulung', 'Zerspaner', 'Rente', 'Staat im Staat', 'Schwester', 'Ziegelei', 'Krebs', 'Lungenemphysem', 'Reisen', 'Urlaub', 'Spanien', 'Wiedervereinigung', 'anerkannte Berufskrankheit', 'Krankenhaus', 'Städte der Witwen', 'Lungenkrebs', 'Radon', 'Alkohol', 'akzisefreier Schnaps', 'Aufklärung über Gefahren', 'Todesursachen', 'Radon in Gebäuden', 'Verschleierung der Gefahren', 'Versicherung', 'Versicherungsbezirk', 'Tupperware', 'Reisen in der Rente', 'Kalter Krieg', 'Krieg', 'Verwandtschaft', 'Kinderwunsch', 'Abfindungen', 'selbständige Republik Schwarzenberg', 'Sozialismus', 'Glaube an den Sozialismus', 'FDJ', 'SED', 'Parteimitglied', 'Taufe', 'Konfirmation', 'Namensgebung', 'Jugendweihe', 'Enttäuschung mit der DDR', 'Demonstrationen', 'Arbeitsalltag', 'Work-Life-Balance', 'Ernährung', 'Wismut-Küche', 'Marken', 'Marken und Talons', 'Anwerbung zur SED', 'Gewerkschaft', 'Vertrauensfrau', 'DSF', 'Auszeichnungen', 'Armeegarnison', 'Frauentag', 'Deutscher Frauenbund', 'Kontakt zu sowjetischen Kollegen', 'Frauenbrigade', 'Sanierung', 'Halden', 'Umwelt', 'Umweltschäden', 'Schlammteich'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-bohnwagner-elfriede', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/reiner-brumme
# {'Orig_ID': '6ce5974b9c6d4deda119aa6ba5737fa9', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-01-28', 'Length': '3:12:16', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['SED Gebietsleitung Wismut', 'Wismut Wohngebiet', 'Barackenlager', 'Gesundheitswesen', 'Staat im Staate', 'Lebensmittelkarten', 'rollende Woche', 'Schichtsystem', 'Wismut Küche', 'Essensmarken', 'Marken und Talons', 'Preis', 'NSW', 'Schule', 'Schlossschule', 'Förderschule', 'Erkundung', 'Erkundungsraster', 'Bohrung', 'Expedition', 'Polytechnische Oberschule', 'Abitur', 'Landmaschinen- und Traktorenschlosser', 'Facharbeiter', 'Internat', 'Jurist', 'Wirtschaftsjurist', 'Schlesien', 'Sibirien', 'Vertragsrussisch', 'Vertragsenglisch', 'Sowchos', 'Kolchose', 'LPG', 'Aktivist', 'Beststudent', 'FDJ-Zentralrat', 'Zentraler Geologischer Betrieb', 'Gehaltsgruppe', 'Territorialbetrieb', 'Sächsische Geologische Erkundungstruppe', 'Bilanz', 'Dienstreisen', 'Sowjetische Spezialisten', 'Sowjetische Armee', 'technische Bohrungen', 'Trinkwasserbohrung', 'Mineraloge', 'Bohrtechnologe', 'Braunkohlebetrieb', 'Kombinat', 'Arbeiterwohnunterkunft', 'Parteisekretär', 'Abteilung', 'Sicherheit Ordnung und Geheimnisschutz', 'Vertragsverhandlungen', 'Braunkohle', 'Zinnerz', 'ZGI', 'Geofernerkundung', 'Geheimhaltung', 'Verschlusssache', 'Unsinn der Geheimhaltung', 'Saboteure', 'Agenten', 'Vater', 'Laugung', 'Yellow Cake', 'Mutter', 'Oberlaborantin', 'Aufbereitung'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-brumme-reiner', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/rudolf-daenecke
# {'Orig_ID': 'fbe5e05422774bf0b913050c74057f6c', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-01-21', 'Length': '3:11:22', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Tschechien', 'Sudetenland', 'Volksschule', 'Vater', 'Lokführer', 'Deutsche Reichsbahn', 'Lehre', 'Studium', 'Bergingenieur', 'Tiefbau', 'Leitungstätigkeit', 'Assistent', 'Steiger', 'Dispatcher', 'Untersuchungstechnische Projektierungsabteilung', 'Versetzung', 'Erdölindustrie', 'SED', 'Partei', 'Mitglied', 'Voraussetzung', 'Oberdispatcher', 'Tagebau', 'Geophysiker', 'Obersteiger', 'Parteischule', 'Familie', 'Kinder', 'Parteisekretär', 'Brand', 'Brände', 'Brandbekämpfung', 'Haldenbrand', 'Revierleiter', 'Leiter der technischen Abteilung', 'Diplomingenieur', 'Diplom Bergingenieur', 'technische Vorbereitung', 'Versatzarbeiten', 'Koordinator', 'Betriebe', 'Promotion', 'Dr.-Ing.', 'Vorlesungen', 'Leitungsaufgaben', 'technischer Direktor', 'Geheimhaltung', 'Ausland', 'RGW', 'Gefahr', 'Geheimnisverrat', 'Überwachung', 'Stasi', 'Staatssicherheit', 'Scheidung', 'Flucht', 'Rückgang der Uranproduktion', 'Freier Markt', 'Abfahrkonzept', 'Einstellung des Bergbaus', 'Konzept', 'Beratungsfirma', 'Vorstand der Sparte Bergbau', 'Sanierungskonzept', 'Auslandsreisen', 'Wissenstransfer', 'USA', 'Kanada', 'Australien', 'Schlammteich', 'Tailings', 'Sanierungskosten', 'Wismut GmbH', 'Hauptabteilungsleiter', 'Generalbevollmächtigter', 'Sanierungsdurchführung', 'Altstandorte', 'Finanzierung', 'Vertrag', 'Traditionsverein', 'Anwerbung', 'Gehalt', 'Verdienst', 'Lohn', 'Internat', 'Untertage', 'Übertage', 'Fachschule', 'Fachhochschule', 'Fernstudium', 'Ehe', 'Sohn', 'Lungenkrebs', 'Parteimitglied', 'Arbeiterklasse', 'Kandidatenzeit', 'Angestellte', 'Parteiversammlungen', 'Verantwortung', 'Versetzungen', 'Privatleben', 'Arbeitsablauf', 'Krankheit', 'Produktionssteuerung', 'Planerfüllung', 'Plan', 'Belastung', 'Wende', 'BRD', 'Kindergarten', 'Frau', 'Arztsekretärin', 'Wismut-Kinderkrippen', 'Wohnungen', 'Tochter', 'Ausreise', 'Kontaktverbot', 'Ausreiseantrag', 'Sohn', 'Wehrdienstverweigerer', 'Umweltaktivist', 'Republikflucht', 'Protest', 'Beleites', 'Stasi', 'Überwachung', 'Havarie'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-daenecke-rudolf', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/kerstin-nindel
# {'Orig_ID': '3c8164ec6f894a6c95b507a323fb232a', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-02-24', 'Length': '2:17:23', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Promotion', 'Diplomarbeit', 'Stipendium', 'Uranisotope', 'Uran', 'Zinn', 'Erz', 'Metall', 'Wissenschaft', 'Naturwissenschaft', 'Geologie', 'Feldgeologie', 'Hydrogeologie', 'Geotechnik', 'Physik', 'Biologie', 'Grundwasser', 'Gewässerbelastung', 'Gestein', 'Wohnen', 'Frauen', 'Kinder', 'Krippen', 'Arbeitsschutz', 'Strahlenschutz', 'Umweltschutz', 'DFA', 'Afög', 'Wissenschaftlich-Technisches Zentrum', 'Geologischer Betrieb Grüna', 'Projektierungsbetrieb', 'Projektierung', 'Kienbaum AG', 'Sanierung', 'Consulting & Engineering', 'Landschaft', 'Labor', 'Gesundheitswesen', 'Gesundheit', 'Emanzipation', 'Geschlechterrollen', 'Umstrukturierung', 'Kurzarbeit', 'Monitoring', 'Gutachten', 'SDAG Wismut', 'Wismut GmbH', 'Feriengestaltung', 'Staat im Staate', 'Proteste', 'Begrüßungsgeld', 'Checkpoint Charlie', 'Einigungsvertrag', 'LDPD', 'SED', 'FDJ', 'Pioniere', 'MfS', 'Braunkohle', 'Hinterlassenschaften', 'BMWi', 'Kernkraft', 'Atomkraft', 'Umweltgruppen', 'Krankheit', 'Schneeberger Krankheit', 'Radium', 'Radon', 'Strahlen', 'Kernfusion', 'Frauentag', 'Muttertag', 'Rente', 'Identität', 'Tagebau', 'Bohrkern', 'Mutterschutz', 'Elternzeit', 'Brigadetagebuch', 'Ingenieurbüro'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-nindel-kerstin', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/gunter-ducke
# {'Orig_ID': '313f9365d950442d90ec4467143038a7', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-06-11', 'Length': '2:38:23', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Lehre', 'Abitur', 'Feinoptiker', 'Studium im Ausland', 'Vater', 'Schlosser', 'Erkundung von Lagerstätten', 'Bergbaustudium', 'Staub', 'Staubschutz', 'Gesundheits- und Arbeitsschutz', 'Nassbohren', 'Technik und Medizin', 'technische Arbeitshygiene', 'DDR', 'Verbesserungen', 'Parteilinie', 'Silikose', 'ärztliche Silikosekommission', 'Lebensstil der Bergleute', 'Kampf um die Arbeitssicherheit', 'Überzeugung der Bergleute', 'Frührente', 'Bereichsleiter für Gefahrstoffschutz und Berufskrankheiten', 'Asbest', 'Krebs', 'Asbest bei der Wismut', 'Arbeitskreis Arbeitsmedizin', 'Krebsursachen', 'Medien', 'Berichterstattung', 'westliche Medien', 'Betriebe der Wismut', 'Trinkbranntwein', 'Kumpeltod', 'Schnapsmarken', 'stille Währung', 'IG Bergbau', 'IG Wismut', 'Promotion', 'Schlaganfall', 'mechanische Werkstatt', 'Optikfertigung', 'Gesellenbrief', 'Empfehlung zum Studium', 'zweiter Bildungsweg', 'technische Intelligenz', 'Staatserlass', 'Bergingenieur', 'Diplom-Ingenieur', 'Studium in der Sowjetunion', 'Russischunterricht', 'Ehefrau', 'Gefahren von Uran', 'Spezialisierung auf Staubschutz', 'Arbeitsablauf', 'Produktionsfunktionär', 'Partei', 'politische Konflikte', 'dialektische Herangehensweise', 'Medienkritik', 'Tätigkeit in der Generaldirektion', 'vertrauliche Dienstsache', 'Asbestforschung', 'Geheimhaltung', 'Staatssicherheit', 'Stasi', 'außerplanmäßige Aspirantur', 'Bergbauberufsgenossenschaft', 'FDJ', 'SED', 'Gewerkschaft', 'DSF', 'Urania', 'Gesellschaft für Sport und Technik', 'Dienstreisen', 'Staat im Staat', 'Umweltbewegung', 'Umweltproteste', 'Rente', 'Strukturwandel', 'Strukturwandel der Wismut'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-ducke-dr-guenter', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/hans-georg-fischer-1
# {'Orig_ID': 'b634f41db700421f8f021663effba332', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2020-09-09', 'Length': '3:02:19', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Jugendlager', 'Facharbeiter für Bergbautechnologie', 'Lehre', 'Anwerbung', 'Hauerbrigade Pschiebel', 'Hauerbrigade Peter Bergner', 'Ausbildung', 'Sprenger', 'Drittelhauer', 'Hauer', 'Vertrauensmann', 'Jugendbrigade Bergner', 'Jugendbrigade Juri Gagarin', 'Kollektiv der sozialistischen Arbeit', 'Aktivist der sozialistischen Arbeit', 'Bergbaubetrieb DSF Reust', 'Wehrdienst', 'NVA', 'Artur-Becker-Medaille', 'FDJ', 'Brigadier', 'Grubenwehr', 'Wende', 'Friedliche Revolution', '1989', 'Sanierung', 'Silberne Ehrennadel der Grubenwehr', 'DEKRA-Lehrgang für Baumaschinenführer', 'Halde', 'Haldensanierung', 'Haldenabtrag', 'Bediener Großraumtechnik', 'Baumaschinenführer', 'Flächensanierung', 'Krebs', 'Krankheit', 'Ruhestand', 'Altersrente', 'Familie', 'Kind', 'SED', 'Erzabbau', 'Erzförderung', 'Yellow Cake', 'Technologie', 'Uranoxid', 'Uranerz', 'Radon', 'Bewetterung', 'Strahlung', 'Schichtlohnsystem', 'Schichtlohn', 'Lohn', 'Zuschläge', 'Planwirtschaft', 'Berufe', 'Schlosser', 'Elektriker', 'Bereichsschlosser', 'Dammbaubrigade', 'Steiger', 'Obersteiger', 'Geologe', 'Hauptingenieur', 'Revierleiter', 'Unfall'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-fischer-hans-georg', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/bernd-freyer
# {'Orig_ID': '310fcb8c326743449adac8998576b9d9', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-05-27', 'Length': '3:10:59', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Hauer', 'Lehrling', 'Volkshochschule', 'Arbeiter- und Bauernfakultät', 'Tiefbohrtechnik', 'Ingenieurökonom', 'Ingenieurökonomie', 'Tiefbau', 'Studium', 'WTZ', 'Wissenschaftlich-Technisches Zentrum', 'Anwerbung', 'Leitungstätigkeit', 'kybernetische Methoden', 'mathematische Methoden', 'ökonomischer Leiter', 'Bildung', 'Arbeitsgruppe', 'Umstrukturierung', 'Objekt 90', 'Auflösung von Objekt 90', 'Thüringen', 'Projekt zur Umgestaltung der Wismut', 'Ausbildung', 'Weiterbildung', 'Aus- und Weiterbildungsabteilung', 'Gestaltung der Weiterbildung', 'Wissenschaftlicher Mitarbeiter', 'Mitarbeiter des stellvertretenden Generaldirektors', 'Zurückversetzung in die Produktion', 'Materialwirtschaft', 'Abteilungsleiter', 'Familie', 'Geschwister', 'Vater', 'Silikose', 'Lungenkrankheit', 'Wohnungsfrage', 'FDJ', 'Partei', 'stellvertretender Fachdirektor', 'Delegierung', 'Aspirantur', 'Soziologie', 'Ulbricht', 'System der neuen ökonomischen Planung', 'Mangelwirtschaft', 'Materialverbrauch', 'Materialverbrauchsnormen', 'Konferenzen', 'Rolle der SED', 'Staat im Staat', 'Selbstversorgung', 'Autarkie', 'Modernität', 'Leiter der 22. Abteilung', 'Steuerung der Beschaffungsprozesse', 'Material', 'Ausrüstungen', 'Abteilung Absatz', 'Technischer Kontor', 'Materialbilanzen', 'Lagerprobleme', 'Konsumgüterproduktion', 'Planwirtschaft', 'Waluta', 'Schonplatz', 'Arbeitsunfähigkeit', 'Verträge', 'Ausgaben', 'Umsatz', 'Umweltschutz', 'Umweltschäden', 'die wilden Jahre', 'Umweltbewusstsein', 'Uranvorkommen', 'Wismut Epochen', 'Wende', 'Umstrukturierungen', 'Abfindungen', 'Regulierung von sozialökonomischen Systemen', 'geringerer Uranbedarf', 'Tauwetter', 'Modernisierung', 'Mechanisierung', 'arme Lagerstätten', 'Westkontakte', 'Stimmung der Wende', 'Treuhand', 'Bürger zweiter Klasse', 'Fondträger 7211', 'Politbüro', 'Importeur und Exporteur der SDAG Wismut', 'Denunzianten', 'IM', 'Öffnung der Geheimhaltung', 'Öffentlichkeitsarbeit', 'Presse', 'Marktwirtschaft', 'Liquidierung', 'neue Wismut Sparten', 'Rente', 'Kündigungen', 'Ende der Uranerzförderung', 'Kontakt zu sowjetischen Spezialisten', 'Hauptingenieur', 'Fachdirektor Produktion', 'Deutsch-sowjetische Freundschaft', 'Mitarbeiterzahlen', 'Freundschaften', 'Konflikte', 'Mitglied der SED', 'Gewerkschaft', 'Urania', 'Identität', 'Sanierung', 'Krankheiten'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-freyer-bernd-prof-dr', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/klaus-friedrich
# {'Orig_ID': '92c87212a65346f98d0e97ac4e130b3a', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-02-19', 'Length': '2:36:20', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Georg-Agricola-Oberschule', 'Schulzeit', 'Medizinstudium', 'Hürden', 'Keine Erstzulassung', 'NVA', 'Funker', 'Nachrichtenkompanie', 'Ministerium für nationale Verteidigung', 'Alarmauslösung', 'Grenzschließung', 'Kommunikationssperre', 'Kriegsangst', 'Promotion', 'Bewerbung bei der Wismut', 'Gesundheitswesen Wismut', 'Ausbildung', 'Gesundheitliche Betreuung der Bergleute', 'Bedeutung der Wismut als Lebensinhalt', 'Facharzt Arbeitsmedizin', 'Unfälle', 'Belegarbeit', 'Thüringer Abbaurevier', 'Chef eines Laboratoriums', 'Direktor des Arbeitsmedizinischen Zentrums', 'Stollberg', 'Schachtambulatorium', 'Wendezeit', 'Abwicklung der medizinischen Einrichtungen', 'Scheitern der Erhaltung', 'Entlassung von Mitarbeitern', 'Berufsgenossenschaftlicher Arbeitsmedizinischer Dienst', 'Betriebsarzt bei der Wismut', 'Arbeitskreis zu Belastungen von ehemaligen Bergarbeitern', 'Zentrale Betreuungsstelle Wismut', 'nachgehende Betreuung', 'Belastungsbeanspruchungen', 'Kriterien zur Anerkennung von Berufserkrankungen', 'Erkrankungen durch Strahlung', 'Erarbeitung von Untersuchungsprogrammen', 'Erfassung von lebenden Bergleuten', 'Untersuchungen von Bergleuten', 'Rekrutierung von Ärzten', 'Entwicklung von Fortbildungen für Ärzte', 'Tod der Ehefrau', 'Ärztin', 'Grubenwehr', 'Einfahrt mit der Grubenwehr', 'Betriebsambulatorium', 'Sprengunfall', 'Verschüttung', 'Vater', 'Gewerbetreibender', 'Arbeitsmedizin', 'Elternhaus', 'Mutter', 'Haufrau', '"Mithelfende Ehefrau"', 'Mauer', 'Berliner Mauer', 'Arbeitsalltag', 'Aufgaben der Arbeitsmedizin', 'Sprenggase', 'Schaffung von Grenzwerten', 'Staubbelastung', 'Staubbekämpfung', 'Trockenbohren', 'Nassbohren', 'Durchsetzung des Nassbohrens', 'Schichtröntgen', 'Röntgenzug', 'Röntgen', 'Belüftung', 'Bewetterung', 'Radon', 'Etappen der Wismut', 'Epochen der Wismut', 'Wilden Jahre der Wismut', 'Kurbad', 'Marken und Talons', 'Gute Versorgung', 'Zwangsverpflichtung', 'Bergarbeiter-Unterkünfte', 'fehlende Infrastruktur', 'Entwicklung des Arbeitsschutzes', 'Tauglichkeit', 'Überwachungsuntersuchung', 'Silikose', 'Rehabilitation', 'Rehabilitationskommission'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-friedrich-klaus-dr', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/siegfried-geyer
# {'Orig_ID': 'b2d83e7a08d740a193ffcb2042864dad', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-06-11', 'Length': '2:40:18', 'Accessibility': 'Online Open Access', 'Interviewer': 'Astrid Mignon Kirchhof', 'Indexing': ['Kindheit', 'Einschulung', 'finanzielle Schwierigkeiten', 'Lehre', 'Kohlenproduktion', 'Steinkohle', 'Anwerbung', 'Lehrhauer', 'Grubenunglück', 'Praktikum', 'Montanchemie', 'Tiefbohrtechnik', 'Studium der Chemie', 'Frau', 'Kind', 'Wohnung', 'Geldprobleme', 'Arbeitsbeginn bei der Wismut', 'Stoß- und Firstenbau', 'Muffenausbau', 'Kastenausbau', 'Kollektiv', 'Zusammenhalt', 'Belastung', 'Krankheiten', 'Bergmann', 'Abitur', 'Fernstudium', 'Ingenieur', 'Steiger', 'Obersteiger', 'Hauer', 'Gehalt', 'Sprengungen', 'Diplom-Ingenieur', 'Tiefbau', 'Moskauer Studenten', 'Studentenaustausch', 'Grubenbereiche', 'Grubenbereich 1', 'Kontakt zu sowjetischen Spezialisten', 'Plan', 'Planerfüllung', 'Planwirtschaft', 'Produktionsdirektor', 'künstliche Kühlung', 'Untertage', 'Aufbereitung', 'Arsenanteil im Uran', 'Marktkonkurrenz zu China', 'Wolfram', 'Besucherbergwerk', 'Sanierung', 'Leiter der Sanierung über- und unter Tage', 'Stellvertretender Fachdirektor', 'Abberufung', 'Ende der Wismut', 'Streiks', 'Arbeitskämpfe', 'Bergmannsrente', 'Umstrukturierung der Wismut', 'Restabbau', 'letzter Hunt', 'Flutung der Gruben', 'Abschlussbetriebsplan', 'Bürokratie', 'Arbeit mit Behörden', 'Ministerratsbeschluss', 'Abfindungen', 'Arbeitsförderungsgesellschaft', 'Umschulung', 'Auffanggesellschaft', 'radiometrische Aufbereitung', 'Abteilung Grube Aue', 'Grubenlüfter', 'Ventilator', 'Aufbau der Wetterführung', 'Verfüllung der Schächte', 'Plomben', 'Abwetterschacht', 'Abwetterschacht 382', 'Umfunktionierung vom Frischwetterschacht zum Abwetterschacht', 'Wasserhaltung', 'Gifte im Wasser', 'Wasserreinigung', 'Beruf', 'Krankenschwester', 'Wohnungssuche', 'WG-Wohnungen', 'Frauen bei der Wismut', 'Havarien', 'Umweltproteste', 'Silikose', 'Lärmschaden', 'Pressluftschaden', 'Rauchen unter Tage', 'Krebs', 'Lungenkrebs', 'Prostatakrebs', 'Partei', 'SED', 'Parteimitglied', 'FDJ', 'Delegation', 'Delegation nach Berlin', 'Parteitag', 'Rente', 'Staat im Staat', 'Ablauf der Sanierung', 'Halden', 'Radiumbad', 'Marx-Semler-Stolln', 'Halde 250', 'Radiumbad unter Tage'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-geyer-siegfried', 'Interviewtyp': 'Zeitzeugeninterview'}
# person URL: https://wismut.saw-leipzig.de/api/de/personen/jurij-michajlowitsch-gorbatschjow
# {'Orig_ID': '53040356d3104e419dfcd1d2d16da308', 'Medium': 'Video', 'Language': 'de', 'Date_of_Interview': '2021-03-18', 'Length': '2:15:46', 'Accessibility': 'Online Open Access', 'Interviewer': 'Yaroslav Koshelev', 'Indexing': ['Geologe', 'Geophysiker', 'Grubenbrand', 'Brände', 'Assistent', 'Lehrbeauftragter', 'Vorlesungen', 'Suchexpedition', 'Expedition', 'Beryll', 'Anwerbung', 'DDR', 'Bergingenieur', 'Uran', 'Kanada', 'Beurteilung', 'Familie', 'Reaktion', 'Frau', 'Buchhalterin', 'Faschismus', 'Befürchtungen', 'Auswahlverfahren', 'Zugfahrt', 'erste Eindrücke', 'Ankunft in der DDR', 'Generaldirektion', 'Bergbaulandschaft', 'Aue', 'Busse', 'Schichtbusse', 'Schichtsystem', 'sowjetische Siedlung', 'sowjetische Kolonie', 'Förderbetriebe', 'Anreicherungsbetriebe', 'Tschechien', 'Wohnheim', 'Frauenrat', 'Wohnung', 'Komfort', 'Club', 'Spielplätze', 'Sprache', 'deutsche Sprache', 'Sprachbarrieren', 'Einfahrt', 'Untertage', 'deutsche Kollegen', 'Kulturarbeit', 'Sport', 'Wettbewerbe', 'Volleyball', 'Hobbies', 'Schule', 'Theater', 'Reisen', 'Fahrten', 'Jagd', 'Angeln', 'Arbeitsalltag', 'Plan', 'Planerfüllung', 'Planung', 'Vorräte', 'Vorkommen', 'Erzvorkommen', 'Planwirtschaft', 'Probleme', 'Schätzungen', 'Hauptgeologe', 'Beziehungen', 'Diskussionen', 'Kollektiv', 'Bergmannsschulen', 'DDR-Flucht', 'Flucht', 'Mauerbau', 'Geheimhaltung', 'Armee', 'Armeeangehörige', 'uneheliche Kinder', 'die besten Jahre', 'die wilden Jahre', 'Staat im Staat', 'Gesundheitssystem', 'Unfall', 'Sicherheitsvorkehrungen', 'Bohrungen', 'Bohren', 'Trockenbohren', 'Nassbohren', 'Radon', 'Belüftung', 'Ventilation', 'Staub', 'Dosimetrie', 'Krankheiten', 'Lungenkrankheit', 'Heimat', 'Selbstmord', 'Suizid', 'Wende', 'Brüche', 'Sanierung', 'Rekultivierung', 'Rente'], 'link': 'https://wismut.saw-leipzig.de/api/de/bestaende/zeitzeugen-interviews/interview-mit-gorbatschjow-jurij-michajlowitsch', 'Interviewtyp': 'Zeitzeugeninterview'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_31935/3115668649.py in <module>
#      91
#      92 if __name__ == '__main__':
# ---> 93     main()
#      94
#
# /tmp/ipykernel_31935/3115668649.py in main(*starturl)
#      85     interviewliste = find_interviews(rdata)
#      86     print(type(interviewliste))
# ---> 87     metadaten = parse_interviews(interviewliste)
#      88
#      89     #print(rdata)
#
# /tmp/ipykernel_31935/3115668649.py in parse_interviews(urls)
#      46     for url in urls:
#      47         data = read_api(url)
# ---> 48         metadaten = find_metadata_in_interview(data)
#      49         interviews_metadaten.append(metadaten)
#      50     return interviews_metadaten
#
# /tmp/ipykernel_31935/3115668649.py in find_metadata_in_interview(data)
#      63         'Length' : str(datetime.timedelta(seconds=data['duration'])),
#      64         'Accessibility' : 'Online Open Access',
# ---> 65         'Interviewer' : data['interviewer'][0]['title'],
#      66         'Indexing' : data['subjects'],
#      67         'link' : data['@id'],
#
# IndexError: list index out of range

# %% [markdown]
# Basic Functionality

# %%
def write_csv(path_to_csv, rows, **kwargs):
    """*Args*: path_to_csv, rows. *kwargs*: colnames=[]"""
    import csv, sys
    colnames = kwargs.get('colnames', [])
    if not colnames:
        colnames = set()
        for row in rows:
            for colname in row:
                colnames.add(colname)
        colnames = sorted(list(colnames))
    if len(rows):
        with open(path_to_csv, 'w', newline='')  as f:
            csv.register_dialect('custom', delimiter=';')
            colnames = colnames or sorted(rows[0].keys())
            dict_writer = csv.DictWriter(f, colnames, dialect='custom')
            dict_writer.writeheader()
            dict_writer.writerows(rows)
    else:
        sys.stderr.write('No data to write to file "{}"\n'.format(path_to_csv))
    return path_to_csv
